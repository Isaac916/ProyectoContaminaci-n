# %%
import requests
import os
import json
import pandas as pd

# ===================== Funciones de Scraping =====================

def cargar_url():
    base_url = "https://datos.gob.es/apidata/catalog/dataset/a10002983-mediciones-por-horas-de-contaminantes-atmosfericos-y-ozono-de-la-comunitat-valenciana-"
    urls = [f"{base_url}{year}?_sort=title&_pageSize=10&_page=0" for year in range(1994, 2025)]
    return urls

def obtener_anos_url(api_url):
    return api_url.split('-')[-1][:4]

def obtener_datos_url(api_url, year):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    try:
        response = requests.get(api_url, headers=headers)
        response.raise_for_status()
        data = response.json()
        download_folder = f"{year}_csv_files"
        if not os.path.exists(download_folder):
            os.makedirs(download_folder)
        
        def encontrar_descargar_csv(d):
            if isinstance(d, dict):
                for value in d.values():
                    encontrar_descargar_csv(value)
            elif isinstance(d, list):
                for item in d:
                    encontrar_descargar_csv(item)
            elif isinstance(d, str) and d.endswith(".csv"):
                print(f"URL de archivo CSV encontrado: {d}")
                descargar_csv(d, download_folder)

        encontrar_descargar_csv(data)
    except requests.exceptions.RequestException as e:
        print(f"Error al obtener los datos de la API: {e}")

def descargar_csv(csv_url, download_folder):
    try:
        response = requests.get(csv_url, stream=True)
        response.raise_for_status()
        filename = csv_url.split("/")[-1]
        file_path = os.path.join(download_folder, filename)
        with open(file_path, 'wb') as file:
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)
        print(f"Archivo CSV descargado: {filename} en la carpeta {download_folder}")
    except requests.exceptions.RequestException as e:
        print(f"Error al descargar el archivo CSV desde {csv_url}: {e}")

def procesar_anos():
    urls = cargar_url()
    for url in urls:
        year = obtener_anos_url(url)
        print(f"Procesando datos para el año {year}...")
        obtener_datos_url(url, year)

# ===================== Procesamiento de Datos =====================

def procesar_csv():
    base_dir = os.getcwd()
    year_folders = [f for f in os.listdir(base_dir) if os.path.isdir(f) and f.endswith("_csv_files")]
    estaciones = ["ELX - AGROALIMENTARI", "ORIHUELA", "TORREVIEJA"]
    combined_data = pd.DataFrame()

    for folder in year_folders:
        print(f"Procesando la carpeta: {folder}")
        folder_path = os.path.join(base_dir, folder)
        csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

        for csv_file in csv_files:
            csv_path = os.path.join(folder_path, csv_file)
            print(f"Leyendo el archivo: {csv_file}")
            try:
                df = pd.read_csv(csv_path, encoding='utf-8', delimiter=';', on_bad_lines='skip')
                if 'NOM_ESTACION' not in df.columns:
                    print(f"El archivo {csv_file} no contiene la columna 'NOM_ESTACION'.")
                    continue
                df_filtered = df[df['NOM_ESTACION'].isin(estaciones)]
                if not df_filtered.empty:
                    combined_data = pd.concat([combined_data, df_filtered], ignore_index=True)
            except Exception as e:
                print(f"Error al procesar el archivo {csv_file}: {e}")

    if not combined_data.empty:
        output_folder = os.path.join(base_dir, "ESTACIONES_COMBINADAS_NO_LIMPIO")
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)
        output_file = os.path.join(output_folder, "estaciones_combinadas_NO_LIMPIO.csv")
        combined_data.to_csv(output_file, index=False, encoding='utf-8')
        print(f"Archivo combinado de estaciones guardado en: {output_file}")

# ===================== Limpieza de Datos =====================

def limpiezaAutomaticaPorEstacion(dataFrame):
    dataFrame.replace("-", pd.NA, inplace=True)
    columnasImportantes = ['COD_ESTACION', 'NOM_ESTACION', 'FECHA', 'HORA', 'SO2', 'CO', 'NO', 'NO2', 'NOx', 'O3']
    dataFrame = dataFrame[columnasImportantes]
    columnas_con_nulos = ['SO2', 'NO', 'NO2', 'NOx', 'O3']

    for columna in columnas_con_nulos:
        dataFrame[columna] = pd.to_numeric(dataFrame[columna], errors='coerce')
        dataFrame[columna].fillna(dataFrame[columna].mean(), inplace=True)

    dataFrame = dataFrame.dropna(axis=1, thresh=0.5 * len(dataFrame) * 0.5)
    return dataFrame

# ===================== Exportación a JSON y CSV =====================

def dataFrametoJSON(dataFrame, nombre):
    json_object = dataFrame.to_json(orient='records')
    filename = f"{nombre}-LIMPIO.json"
    with open(filename, 'w') as file:
        file.write(json_object)
    print(f"Archivo guardado como {filename}")

# ===================== Ejecución del Script =====================

if __name__ == "__main__":
    procesar_anos()
    procesar_csv()

    # Cargar datos procesados
    dataCompleto = pd.read_csv('./ESTACIONES_COMBINADAS_NO_LIMPIO/estaciones_combinadas_NO_LIMPIO.csv', decimal=",")
    estaciones = ["ELX - AGROALIMENTARI", "TORREVIEJA", "ORIHUELA"]
    conjuntos_datos = {}

    for estacion in estaciones:
        dataEstacion = dataCompleto[dataCompleto["NOM_ESTACION"] == estacion]
        dataEstacionLimpio = limpiezaAutomaticaPorEstacion(dataEstacion)
        conjuntos_datos[estacion] = dataEstacionLimpio

        # Exportar a JSON y CSV
        dataFrametoJSON(dataEstacionLimpio, estacion.replace(" ", "_"))
        dataEstacionLimpio.to_csv(f"{estacion.replace(' ', '_')}-Limpio.csv", sep=";", decimal=",", index=False)
        print(f"Datos limpios exportados para la estación {estacion}.")
# Out:
# Procesando datos para el año 1994...
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13079cca-6ed6-4dec-b99a-788bcaad9ed8/resource/0a2ef8a1-9c8b-46cb-9d34-98a77ffe6807/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199409.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199409.csv en la carpeta 1994_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13079cca-6ed6-4dec-b99a-788bcaad9ed8/resource/98778330-da64-4c87-b536-542211fdb34e/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199404.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199404.csv en la carpeta 1994_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13079cca-6ed6-4dec-b99a-788bcaad9ed8/resource/cd67b5a1-a61c-4b94-a161-043993b42fa5/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199403.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199403.csv en la carpeta 1994_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13079cca-6ed6-4dec-b99a-788bcaad9ed8/resource/1efa15dd-27f7-4dd5-89cd-aed339b8d28a/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199410.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199410.csv en la carpeta 1994_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13079cca-6ed6-4dec-b99a-788bcaad9ed8/resource/7ee50fe1-6d59-4cf8-9194-03bf404c22b7/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199411.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199411.csv en la carpeta 1994_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13079cca-6ed6-4dec-b99a-788bcaad9ed8/resource/118a398b-6bbc-4358-a497-0a1e6f37df36/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199406.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199406.csv en la carpeta 1994_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13079cca-6ed6-4dec-b99a-788bcaad9ed8/resource/a20fec88-c45b-495f-9918-f91e230e6c26/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199405.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199405.csv en la carpeta 1994_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13079cca-6ed6-4dec-b99a-788bcaad9ed8/resource/49653566-bdfb-4bb7-b0db-8c3d94156c21/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199402.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199402.csv en la carpeta 1994_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13079cca-6ed6-4dec-b99a-788bcaad9ed8/resource/bc4ebb40-375d-4e90-87a9-03673273eda5/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199407.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199407.csv en la carpeta 1994_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13079cca-6ed6-4dec-b99a-788bcaad9ed8/resource/37710583-7fe7-494b-9509-4d56d98f0e1d/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199401.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199401.csv en la carpeta 1994_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13079cca-6ed6-4dec-b99a-788bcaad9ed8/resource/6fc491ff-7b4c-44f7-a26c-a817e3a274aa/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199408.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199408.csv en la carpeta 1994_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13079cca-6ed6-4dec-b99a-788bcaad9ed8/resource/14ef038b-33c3-46cf-ae0c-d527c9f7e9b0/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199412.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199412.csv en la carpeta 1994_csv_files
# Procesando datos para el año 1995...
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/8b09b0d9-8446-46eb-adde-ad48d0649b07/resource/44ec53b7-48ef-4730-bf93-effe118cafc6/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199506.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199506.csv en la carpeta 1995_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/8b09b0d9-8446-46eb-adde-ad48d0649b07/resource/bbb59bbd-2e77-4115-9c7c-e4c756a96fd8/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199503.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199503.csv en la carpeta 1995_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/8b09b0d9-8446-46eb-adde-ad48d0649b07/resource/8d230431-d336-45db-8cf6-e8ea74a89b3e/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199502.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199502.csv en la carpeta 1995_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/8b09b0d9-8446-46eb-adde-ad48d0649b07/resource/0f085143-7c27-49de-ae77-1f473a22c594/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199507.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199507.csv en la carpeta 1995_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/8b09b0d9-8446-46eb-adde-ad48d0649b07/resource/d0e1e744-9194-4253-8522-40af0312d358/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199504.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199504.csv en la carpeta 1995_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/8b09b0d9-8446-46eb-adde-ad48d0649b07/resource/3a09adef-6a46-4492-8749-fedeb4162c1e/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199512.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199512.csv en la carpeta 1995_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/8b09b0d9-8446-46eb-adde-ad48d0649b07/resource/4c4b0bc1-399c-4cf4-85f4-bbfaff2f2414/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199501.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199501.csv en la carpeta 1995_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/8b09b0d9-8446-46eb-adde-ad48d0649b07/resource/e234a472-25af-43d1-bfba-ee80f75b1585/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199505.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199505.csv en la carpeta 1995_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/8b09b0d9-8446-46eb-adde-ad48d0649b07/resource/064e8a11-a872-4ac1-bc4f-5cf659f2b43d/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199509.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199509.csv en la carpeta 1995_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/8b09b0d9-8446-46eb-adde-ad48d0649b07/resource/47e4c059-a623-4844-ac92-83795357a220/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199508.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199508.csv en la carpeta 1995_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/8b09b0d9-8446-46eb-adde-ad48d0649b07/resource/7f3447a1-d2fe-43c4-bbe3-7aa3bd85d894/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199511.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199511.csv en la carpeta 1995_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/8b09b0d9-8446-46eb-adde-ad48d0649b07/resource/866658e4-8a99-414c-bbcf-5f76f85ccd27/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199510.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199510.csv en la carpeta 1995_csv_files
# Procesando datos para el año 1996...
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/7a5c4277-a3e3-4325-aa63-eda030817a58/resource/28bdf8bf-00f3-4ee2-ab14-9dccb011b64f/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199607.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199607.csv en la carpeta 1996_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/7a5c4277-a3e3-4325-aa63-eda030817a58/resource/5917579e-6235-48a2-b1ac-e428f782ea2e/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199609.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199609.csv en la carpeta 1996_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/7a5c4277-a3e3-4325-aa63-eda030817a58/resource/5a051e00-9241-4be2-8c55-a850919a52b2/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199604.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199604.csv en la carpeta 1996_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/7a5c4277-a3e3-4325-aa63-eda030817a58/resource/e479191b-b24f-4538-91b8-76ca73b96f57/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199602.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199602.csv en la carpeta 1996_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/7a5c4277-a3e3-4325-aa63-eda030817a58/resource/d0591e91-cdc4-41bd-bbbb-b90d1e75e9cf/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199605.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199605.csv en la carpeta 1996_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/7a5c4277-a3e3-4325-aa63-eda030817a58/resource/79a35e65-9dc9-4651-ac2d-9139d9277afa/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199601.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199601.csv en la carpeta 1996_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/7a5c4277-a3e3-4325-aa63-eda030817a58/resource/9c7f9aef-93a4-4101-bf49-db064eb8286a/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199606.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199606.csv en la carpeta 1996_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/7a5c4277-a3e3-4325-aa63-eda030817a58/resource/4d08c488-4de0-4737-9393-244a47a9d808/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199610.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199610.csv en la carpeta 1996_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/7a5c4277-a3e3-4325-aa63-eda030817a58/resource/bf040d78-0559-4fd1-9558-703bfedde780/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199603.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199603.csv en la carpeta 1996_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/7a5c4277-a3e3-4325-aa63-eda030817a58/resource/0d9271b6-95cd-461b-b817-b6739d5ba13b/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199611.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199611.csv en la carpeta 1996_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/7a5c4277-a3e3-4325-aa63-eda030817a58/resource/b4ea7cbf-e40e-41c8-8d08-6bd4811ed650/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199608.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199608.csv en la carpeta 1996_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/7a5c4277-a3e3-4325-aa63-eda030817a58/resource/464777e5-bed9-4be1-b22d-49568c3dc161/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199612.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199612.csv en la carpeta 1996_csv_files
# Procesando datos para el año 1997...
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a3a041de-746f-49f5-a136-e4508cf077cc/resource/8508ae8f-4bad-4e90-9c38-ef4de4c18ee8/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199709.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199709.csv en la carpeta 1997_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a3a041de-746f-49f5-a136-e4508cf077cc/resource/d33e039e-56d9-4a89-9476-2d8d5282ee51/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199705.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199705.csv en la carpeta 1997_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a3a041de-746f-49f5-a136-e4508cf077cc/resource/72005788-2a63-4972-9664-c88e6fc824e6/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199708.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199708.csv en la carpeta 1997_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a3a041de-746f-49f5-a136-e4508cf077cc/resource/4cf84d29-20a3-46de-bc0f-0da32876b81f/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199703.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199703.csv en la carpeta 1997_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a3a041de-746f-49f5-a136-e4508cf077cc/resource/bd4296b4-cfaa-42f0-a17a-fbb357001731/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199707.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199707.csv en la carpeta 1997_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a3a041de-746f-49f5-a136-e4508cf077cc/resource/b3d16c6a-5fbd-4f0e-a695-84109abadf8f/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199711.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199711.csv en la carpeta 1997_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a3a041de-746f-49f5-a136-e4508cf077cc/resource/aab0d76d-3bfd-42f8-80b4-e1aeee118715/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199701.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199701.csv en la carpeta 1997_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a3a041de-746f-49f5-a136-e4508cf077cc/resource/fa98b5b4-cbf6-4454-a5e8-6cb7564d7f88/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199710.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199710.csv en la carpeta 1997_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a3a041de-746f-49f5-a136-e4508cf077cc/resource/c05bfcc3-6a09-4cec-a5f9-3345efe79630/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199706.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199706.csv en la carpeta 1997_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a3a041de-746f-49f5-a136-e4508cf077cc/resource/2f465446-55a6-4063-820e-264106c29d2d/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199704.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199704.csv en la carpeta 1997_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a3a041de-746f-49f5-a136-e4508cf077cc/resource/7ac4560e-c3cb-48e4-a18c-6aaad869eeea/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199702.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199702.csv en la carpeta 1997_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a3a041de-746f-49f5-a136-e4508cf077cc/resource/5856c127-32fc-4bec-8e42-683c7da0891d/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199712.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199712.csv en la carpeta 1997_csv_files
# Procesando datos para el año 1998...
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/c0d866d1-c379-4d94-bf05-3e7be1f7a055/resource/64f5c5e6-dd73-4fd1-acc2-6346124696ad/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199801.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199801.csv en la carpeta 1998_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/c0d866d1-c379-4d94-bf05-3e7be1f7a055/resource/652620c2-3296-46bf-b3ac-b6099388be47/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199805.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199805.csv en la carpeta 1998_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/c0d866d1-c379-4d94-bf05-3e7be1f7a055/resource/ae767b9b-2da0-4a47-83a0-2677e1a76092/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199812.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199812.csv en la carpeta 1998_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/c0d866d1-c379-4d94-bf05-3e7be1f7a055/resource/78e2741a-fd44-4526-9f38-ba056069fd57/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199806.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199806.csv en la carpeta 1998_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/c0d866d1-c379-4d94-bf05-3e7be1f7a055/resource/b5a75629-a204-4654-817f-d7aef839c43a/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199810.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199810.csv en la carpeta 1998_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/c0d866d1-c379-4d94-bf05-3e7be1f7a055/resource/55fa22e9-4b7a-48f4-941c-ccf2f93b0a04/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199803.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199803.csv en la carpeta 1998_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/c0d866d1-c379-4d94-bf05-3e7be1f7a055/resource/dd2babd5-2acf-4889-85e9-334533296573/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199804.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199804.csv en la carpeta 1998_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/c0d866d1-c379-4d94-bf05-3e7be1f7a055/resource/66e7f5ac-288d-4165-af99-0120363cbe44/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199807.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199807.csv en la carpeta 1998_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/c0d866d1-c379-4d94-bf05-3e7be1f7a055/resource/1de7631e-06d0-4107-9c5a-b616ebc66ed4/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199809.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199809.csv en la carpeta 1998_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/c0d866d1-c379-4d94-bf05-3e7be1f7a055/resource/9ef9de43-4b24-4904-86f1-12c95c4a4f68/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199811.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199811.csv en la carpeta 1998_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/c0d866d1-c379-4d94-bf05-3e7be1f7a055/resource/7600a859-6c8e-4601-8605-359903529aac/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199802.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199802.csv en la carpeta 1998_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/c0d866d1-c379-4d94-bf05-3e7be1f7a055/resource/2c29a6e7-70d5-414c-89d2-9149e40ca355/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199808.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199808.csv en la carpeta 1998_csv_files
# Procesando datos para el año 1999...
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b12e4caa-9a3f-4927-b1cb-93a4f6f2c653/resource/29f26103-a372-4325-a7d9-efb84e06fc88/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199910.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199910.csv en la carpeta 1999_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b12e4caa-9a3f-4927-b1cb-93a4f6f2c653/resource/d5a10615-6f2f-4f64-a013-99e6d82447e4/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199903.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199903.csv en la carpeta 1999_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b12e4caa-9a3f-4927-b1cb-93a4f6f2c653/resource/5ab081ca-dab7-4632-9db1-e326fe72e52a/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199909.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199909.csv en la carpeta 1999_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b12e4caa-9a3f-4927-b1cb-93a4f6f2c653/resource/f3b8f4af-12ad-474e-917a-3fe76f29c4ab/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199905.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199905.csv en la carpeta 1999_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b12e4caa-9a3f-4927-b1cb-93a4f6f2c653/resource/889fd19e-783c-4b9a-9ee5-7412cd019980/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199908.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199908.csv en la carpeta 1999_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b12e4caa-9a3f-4927-b1cb-93a4f6f2c653/resource/b4f33878-262b-420b-b498-8c5c65485e03/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199906.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199906.csv en la carpeta 1999_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b12e4caa-9a3f-4927-b1cb-93a4f6f2c653/resource/755a6127-384e-4b5a-b03d-fd5fd6366990/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199907.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199907.csv en la carpeta 1999_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b12e4caa-9a3f-4927-b1cb-93a4f6f2c653/resource/47ac4a08-c730-4912-b893-7431bf84a80d/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199904.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199904.csv en la carpeta 1999_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b12e4caa-9a3f-4927-b1cb-93a4f6f2c653/resource/48fa5315-f59a-4ec9-9620-73739d281de5/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199912.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199912.csv en la carpeta 1999_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b12e4caa-9a3f-4927-b1cb-93a4f6f2c653/resource/0e298580-1837-4076-b5da-77996970a168/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199911.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199911.csv en la carpeta 1999_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b12e4caa-9a3f-4927-b1cb-93a4f6f2c653/resource/66bfc255-1994-4944-9625-f8fd56b3498f/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199902.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199902.csv en la carpeta 1999_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b12e4caa-9a3f-4927-b1cb-93a4f6f2c653/resource/97e7e2a7-675b-42e0-91b6-da5736d6dc9a/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_199901.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_199901.csv en la carpeta 1999_csv_files
# Procesando datos para el año 2000...
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/dcb935ef-acaf-4280-b0f4-6fe7874b61a1/resource/6381bffe-8875-4a70-a6cb-f2ba674d2358/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200002.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200002.csv en la carpeta 2000_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/dcb935ef-acaf-4280-b0f4-6fe7874b61a1/resource/b8937054-92c3-4687-97ba-a7b4b7f9e5f2/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200005.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200005.csv en la carpeta 2000_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/dcb935ef-acaf-4280-b0f4-6fe7874b61a1/resource/e05523c5-47de-49c3-9560-19d69fd630bf/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200010.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200010.csv en la carpeta 2000_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/dcb935ef-acaf-4280-b0f4-6fe7874b61a1/resource/89d72cef-4c0a-4ef7-948d-4d69fa9c85ba/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200008.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200008.csv en la carpeta 2000_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/dcb935ef-acaf-4280-b0f4-6fe7874b61a1/resource/d2277031-bedb-479a-9000-9cede11a4afd/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200003.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200003.csv en la carpeta 2000_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/dcb935ef-acaf-4280-b0f4-6fe7874b61a1/resource/007c59a2-9f48-4fe7-816f-6228a40ccc21/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200004.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200004.csv en la carpeta 2000_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/dcb935ef-acaf-4280-b0f4-6fe7874b61a1/resource/8f32a607-ec97-44ae-a41e-668c91dc4162/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200006.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200006.csv en la carpeta 2000_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/dcb935ef-acaf-4280-b0f4-6fe7874b61a1/resource/e1df769f-d93a-45f5-b23c-8e5a1bed60a3/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200001.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200001.csv en la carpeta 2000_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/dcb935ef-acaf-4280-b0f4-6fe7874b61a1/resource/81016d24-e129-44cd-9a78-c2b869cd61c7/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200011.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200011.csv en la carpeta 2000_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/dcb935ef-acaf-4280-b0f4-6fe7874b61a1/resource/5a9d08ca-9146-412a-baf8-f98c3a588e0f/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200009.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200009.csv en la carpeta 2000_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/dcb935ef-acaf-4280-b0f4-6fe7874b61a1/resource/0cdc3185-4587-4a97-8566-60b24f828e0c/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200012.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200012.csv en la carpeta 2000_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/dcb935ef-acaf-4280-b0f4-6fe7874b61a1/resource/09499d95-001b-45b5-8ab6-9d71952e48c6/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200007.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200007.csv en la carpeta 2000_csv_files
# Procesando datos para el año 2001...
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b86e657c-1ee4-4ea1-9e9a-ac4cc07c526e/resource/a05cd25c-50ec-4a7c-93f9-ef19ac4b9e78/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200101.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200101.csv en la carpeta 2001_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b86e657c-1ee4-4ea1-9e9a-ac4cc07c526e/resource/c5c51d9b-8ed5-442e-8ec4-d71a18872cc7/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200110.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200110.csv en la carpeta 2001_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b86e657c-1ee4-4ea1-9e9a-ac4cc07c526e/resource/bf308835-ae28-4cad-9c2d-86cf6b2d549c/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200104.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200104.csv en la carpeta 2001_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b86e657c-1ee4-4ea1-9e9a-ac4cc07c526e/resource/d46bf525-8634-4903-a33c-29f0219ec1e6/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200111.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200111.csv en la carpeta 2001_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b86e657c-1ee4-4ea1-9e9a-ac4cc07c526e/resource/65610e7e-7e81-44dd-b276-4479a5f2c1d1/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200106.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200106.csv en la carpeta 2001_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b86e657c-1ee4-4ea1-9e9a-ac4cc07c526e/resource/6aaf90b0-9a1b-43e0-bf8a-52d4e21f4181/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200109.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200109.csv en la carpeta 2001_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b86e657c-1ee4-4ea1-9e9a-ac4cc07c526e/resource/b08dc814-bacc-4439-b3d7-cc5f10bd26da/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200103.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200103.csv en la carpeta 2001_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b86e657c-1ee4-4ea1-9e9a-ac4cc07c526e/resource/26b00d72-b9a9-43b6-87b1-dfab74095123/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200102.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200102.csv en la carpeta 2001_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b86e657c-1ee4-4ea1-9e9a-ac4cc07c526e/resource/c8f19f41-614c-407f-b865-72ee5524e9e5/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200105.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200105.csv en la carpeta 2001_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b86e657c-1ee4-4ea1-9e9a-ac4cc07c526e/resource/1099cc01-0b6c-4273-82fc-1e890e89b094/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200107.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200107.csv en la carpeta 2001_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b86e657c-1ee4-4ea1-9e9a-ac4cc07c526e/resource/555b30d8-b15a-4131-8215-d9513b1a60d1/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200112.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200112.csv en la carpeta 2001_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/b86e657c-1ee4-4ea1-9e9a-ac4cc07c526e/resource/ff6ff58d-cf31-4f9b-80ad-09006cb9f205/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200108.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200108.csv en la carpeta 2001_csv_files
# Procesando datos para el año 2002...
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a8dd4c21-1540-4a40-9b0f-3309201173a9/resource/61557655-dbe3-42a4-a0e9-b11a868d6520/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200206.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200206.csv en la carpeta 2002_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a8dd4c21-1540-4a40-9b0f-3309201173a9/resource/a4c20f7e-1925-4d31-9f97-902257b7ce81/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200212.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200212.csv en la carpeta 2002_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a8dd4c21-1540-4a40-9b0f-3309201173a9/resource/e80136e0-e903-4dd6-8eea-e4291f71d302/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200201.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200201.csv en la carpeta 2002_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a8dd4c21-1540-4a40-9b0f-3309201173a9/resource/78a9cd65-8700-4983-9315-2348e2be0fc2/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200211.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200211.csv en la carpeta 2002_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a8dd4c21-1540-4a40-9b0f-3309201173a9/resource/79f6399f-046e-43cf-9b5f-cb9d49b51296/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200203.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200203.csv en la carpeta 2002_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a8dd4c21-1540-4a40-9b0f-3309201173a9/resource/11b6f678-ab97-47ca-acf3-66a71c5cd16e/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200205.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200205.csv en la carpeta 2002_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a8dd4c21-1540-4a40-9b0f-3309201173a9/resource/8a68f3f5-5239-4b06-b094-3e1bc56a660f/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200209.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200209.csv en la carpeta 2002_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a8dd4c21-1540-4a40-9b0f-3309201173a9/resource/7e97f5f1-37e3-4566-bc5c-54a1f89220a9/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200202.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200202.csv en la carpeta 2002_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a8dd4c21-1540-4a40-9b0f-3309201173a9/resource/5e99e581-a1a3-4a7b-8236-879449ad680c/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200204.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200204.csv en la carpeta 2002_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a8dd4c21-1540-4a40-9b0f-3309201173a9/resource/390be7ad-c456-41ca-aac6-fd220f16bf84/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200207.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200207.csv en la carpeta 2002_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a8dd4c21-1540-4a40-9b0f-3309201173a9/resource/3e538a9d-361e-41d4-ba53-58c334e1e1d4/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200208.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200208.csv en la carpeta 2002_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/a8dd4c21-1540-4a40-9b0f-3309201173a9/resource/161924af-171e-40ff-9c08-0ef086292888/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200210.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200210.csv en la carpeta 2002_csv_files
# Procesando datos para el año 2003...
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/77780cd8-0ed6-4bc1-bd90-09777f1b3f37/resource/ac63f8f1-41a2-4efc-bfab-910d73c95705/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200311.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200311.csv en la carpeta 2003_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/77780cd8-0ed6-4bc1-bd90-09777f1b3f37/resource/fa7ae032-bb61-4c52-a39b-94dead034c65/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200304.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200304.csv en la carpeta 2003_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/77780cd8-0ed6-4bc1-bd90-09777f1b3f37/resource/24cbd547-f81c-410d-9c27-8a4a84c5c57d/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200306.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200306.csv en la carpeta 2003_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/77780cd8-0ed6-4bc1-bd90-09777f1b3f37/resource/11b3c453-ac61-4411-af95-937f2a370ea4/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200312.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200312.csv en la carpeta 2003_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/77780cd8-0ed6-4bc1-bd90-09777f1b3f37/resource/2ef117d6-5401-4b3d-9bad-54fca8f7e8f4/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200303.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200303.csv en la carpeta 2003_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/77780cd8-0ed6-4bc1-bd90-09777f1b3f37/resource/1743cb41-3d93-4682-9d84-8c1c67b2861f/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200308.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200308.csv en la carpeta 2003_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/77780cd8-0ed6-4bc1-bd90-09777f1b3f37/resource/96752939-8c1a-4658-9e8f-020e84c5690c/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200302.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200302.csv en la carpeta 2003_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/77780cd8-0ed6-4bc1-bd90-09777f1b3f37/resource/0b731537-e62a-4cd1-8f02-3970bff78fd7/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200301.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200301.csv en la carpeta 2003_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/77780cd8-0ed6-4bc1-bd90-09777f1b3f37/resource/27bef74d-09c8-47a8-b884-6421fe7f2bee/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200305.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200305.csv en la carpeta 2003_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/77780cd8-0ed6-4bc1-bd90-09777f1b3f37/resource/8cc44efa-2dd3-4e13-8e40-218a452ddc52/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200307.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200307.csv en la carpeta 2003_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/77780cd8-0ed6-4bc1-bd90-09777f1b3f37/resource/a49edc1e-7f03-4bb2-95ad-5c893da51431/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200309.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200309.csv en la carpeta 2003_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/77780cd8-0ed6-4bc1-bd90-09777f1b3f37/resource/e780a234-f9e1-45ff-b9d8-06f96103731f/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200310.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200310.csv en la carpeta 2003_csv_files
# Procesando datos para el año 2004...
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13798be6-eb74-47dc-b103-740c9c565308/resource/43f38cf3-ef2f-44d3-a1cc-847ab4786aac/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200405.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200405.csv en la carpeta 2004_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13798be6-eb74-47dc-b103-740c9c565308/resource/957a29dc-56f4-46b7-9d51-838888fe8dcb/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200401.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200401.csv en la carpeta 2004_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13798be6-eb74-47dc-b103-740c9c565308/resource/1c27b62a-de7f-4ee7-a00c-65e30d935e15/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200408.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200408.csv en la carpeta 2004_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13798be6-eb74-47dc-b103-740c9c565308/resource/5443b2bd-0841-4e78-9f72-d1a97f22b68a/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200410.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200410.csv en la carpeta 2004_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13798be6-eb74-47dc-b103-740c9c565308/resource/ab074df2-a6d8-4650-b6ef-5a57da612c6c/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200403.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200403.csv en la carpeta 2004_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13798be6-eb74-47dc-b103-740c9c565308/resource/551a26a4-a25a-4765-988d-ab31608173f1/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200404.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200404.csv en la carpeta 2004_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13798be6-eb74-47dc-b103-740c9c565308/resource/32f8f4be-a598-419e-b7d2-a8b932147236/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200411.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200411.csv en la carpeta 2004_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13798be6-eb74-47dc-b103-740c9c565308/resource/cc50c40e-94d5-47a3-aebe-955bf481a3e9/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200407.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200407.csv en la carpeta 2004_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13798be6-eb74-47dc-b103-740c9c565308/resource/ea7bf1f9-4363-4068-be5a-bfd5fa886af0/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200412.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200412.csv en la carpeta 2004_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13798be6-eb74-47dc-b103-740c9c565308/resource/02c7d57b-8cd0-41e2-a057-31be7a0ef333/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200409.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200409.csv en la carpeta 2004_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13798be6-eb74-47dc-b103-740c9c565308/resource/7279ebcb-dc16-48bc-8915-d146ff7c024a/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200406.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200406.csv en la carpeta 2004_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/13798be6-eb74-47dc-b103-740c9c565308/resource/ec5ccbb1-0579-403c-9ed4-554260e182d9/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200402.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200402.csv en la carpeta 2004_csv_files
# Procesando datos para el año 2005...
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/2006e398-b738-4ec2-adb0-2bed46a113d4/resource/874dd568-ff54-4fa0-b252-f1f1640df333/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200501.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200501.csv en la carpeta 2005_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/2006e398-b738-4ec2-adb0-2bed46a113d4/resource/b9c6a0a3-d310-4b4e-b4b0-e5db7f71d603/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200511.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200511.csv en la carpeta 2005_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/2006e398-b738-4ec2-adb0-2bed46a113d4/resource/842d1149-2014-4d89-a22d-b19bedf492e0/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200507.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200507.csv en la carpeta 2005_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/2006e398-b738-4ec2-adb0-2bed46a113d4/resource/9bb916c5-c995-4a6a-a7d1-d37e70857907/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200509.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200509.csv en la carpeta 2005_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/2006e398-b738-4ec2-adb0-2bed46a113d4/resource/c81996b6-bdfc-44dc-aa35-2734a243a7b0/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200503.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200503.csv en la carpeta 2005_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/2006e398-b738-4ec2-adb0-2bed46a113d4/resource/f042dc06-d479-49c9-bb86-d047a3a3222d/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200506.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200506.csv en la carpeta 2005_csv_files
# URL de archivo CSV encontrado: https://dadesobertes.gva.es/dataset/2006e398-b738-4ec2-adb0-2bed46a113d4/resource/e2a28675-1167-485e-be87-8b424489429a/download/contaminacion-atmosferica-y-ozono-promedios-por-horas_200512.csv
# Archivo CSV descargado: contaminacion-atmosferica-y-ozono-promedios-por-horas_200512.csv en la carpeta 2005_csv_files
# ...
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202002.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202003.csv
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:78: DtypeWarning: Columns (10,11,12,17,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, encoding='utf-8', delimiter=';', on_bad_lines='skip')
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202004.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202005.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202006.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202007.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202008.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202009.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202010.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202011.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202012.csv
# Procesando la carpeta: 2021_csv_files
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202101.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202102.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202103.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202104.csv
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:78: DtypeWarning: Columns (17,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, encoding='utf-8', delimiter=';', on_bad_lines='skip')
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202105.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202106.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202107.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202108.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202109.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202110.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202111.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202112.csv
# Procesando la carpeta: 2022_csv_files
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202201.csv
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:78: DtypeWarning: Columns (10,11,12,17,18,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, encoding='utf-8', delimiter=';', on_bad_lines='skip')
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202202.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202203.csv
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:78: DtypeWarning: Columns (10,11,12,17,18,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, encoding='utf-8', delimiter=';', on_bad_lines='skip')
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202204.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202205.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202206.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202207.csv
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:78: DtypeWarning: Columns (17,18,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, encoding='utf-8', delimiter=';', on_bad_lines='skip')
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202208.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202209.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202210.csv
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:78: DtypeWarning: Columns (10,11,12,17,18,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, encoding='utf-8', delimiter=';', on_bad_lines='skip')
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202211.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202212.csv
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:78: DtypeWarning: Columns (17,18,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, encoding='utf-8', delimiter=';', on_bad_lines='skip')
# Procesando la carpeta: 2023_csv_files
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202301.csv
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:78: DtypeWarning: Columns (10,11,12,17,18,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, encoding='utf-8', delimiter=';', on_bad_lines='skip')
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202302.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202303.csv
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:78: DtypeWarning: Columns (10,11,12,17,18,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, encoding='utf-8', delimiter=';', on_bad_lines='skip')
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202304.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202305.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202306.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202307.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202308.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202310.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202311.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202312.csv
# Procesando la carpeta: 2024_csv_files
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202401.csv
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:78: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, encoding='utf-8', delimiter=';', on_bad_lines='skip')
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202402.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202403.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202404.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202405.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202406.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202407.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202408.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202409.csv
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202410.csv
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:78: DtypeWarning: Columns (10,11,12,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, encoding='utf-8', delimiter=';', on_bad_lines='skip')
# Leyendo el archivo: contaminacion-atmosferica-y-ozono-promedios-por-horas_202411.csv
# Archivo combinado de estaciones guardado en: c:\Users\snkle\Desktop\Ingesta\ESTACIONES_COMBINADAS_NO_LIMPIO\estaciones_combinadas_NO_LIMPIO.csv
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:127: DtypeWarning: Columns (34,37,39,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataCompleto = pd.read_csv('./ESTACIONES_COMBINADAS_NO_LIMPIO/estaciones_combinadas_NO_LIMPIO.csv', decimal=",")
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame.replace("-", pd.NA, inplace=True)
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame[columna] = pd.to_numeric(dataFrame[columna], errors='coerce')
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:106: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataFrame[columna].fillna(dataFrame[columna].mean(), inplace=True)
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame[columna].fillna(dataFrame[columna].mean(), inplace=True)
# Archivo guardado como ELX_-_AGROALIMENTARI-LIMPIO.json
# Datos limpios exportados para la estación ELX - AGROALIMENTARI.
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame.replace("-", pd.NA, inplace=True)
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame[columna] = pd.to_numeric(dataFrame[columna], errors='coerce')
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:106: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataFrame[columna].fillna(dataFrame[columna].mean(), inplace=True)
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame[columna].fillna(dataFrame[columna].mean(), inplace=True)
# Archivo guardado como TORREVIEJA-LIMPIO.json
# Datos limpios exportados para la estación TORREVIEJA.
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame.replace("-", pd.NA, inplace=True)
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame[columna] = pd.to_numeric(dataFrame[columna], errors='coerce')
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:106: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataFrame[columna].fillna(dataFrame[columna].mean(), inplace=True)
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame[columna].fillna(dataFrame[columna].mean(), inplace=True)
# Archivo guardado como ORIHUELA-LIMPIO.json
# Datos limpios exportados para la estación ORIHUELA.
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame.replace("-", pd.NA, inplace=True)
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame[columna] = pd.to_numeric(dataFrame[columna], errors='coerce')
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:106: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataFrame[columna].fillna(dataFrame[columna].mean(), inplace=True)
# C:\Users\snkle\AppData\Local\Temp\ipykernel_21284\1259336905.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame[columna].fillna(dataFrame[columna].mean(), inplace=True)
# Archivo guardado como ALACANT_-_EL_PLA-LIMPIO.json
# Datos limpios exportados para la estación ALACANT - EL PLA.
